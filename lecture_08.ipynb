# %%
# plotting time series data

# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

# %%
# data 
dates = [
    datetime(2019,5,24),
    datetime(2019,5,25),
    datetime(2019,5,26),
    datetime(2019,5,27),
    datetime(2019,5,28),
    datetime(2019,5,29),
    datetime(2019,5,30) 
]
y=[0,1,3,4,6,5,7]

# %%
# applying style (beauty)
plt.style.use('ggplot')


plt.plot_date(dates,y, linestyle='solid')

#get current figer gcf
# this basically rotating dates
plt.gcf().autofmt_xdate()


plt.xlabel('dates')
plt.ylabel('y')
plt.title('time series data')


#show grid
plt.grid(True)

plt.show()
